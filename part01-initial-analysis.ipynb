# %% [markdown]
# # Introduction

# %% [markdown]
# > **Will it rain tomorrow?**
#
# That is the question we will try to answer in this project, practicing machine learning.
#
# ## Context
#
# A vacation of a group of friends is about to start and they will arrive at the Melbourne Airport tomorrow in the afternoon. They rented a place near the airport and they want to go on foot to the rented place to save money in the beginning of their trip. But, if it is raining, they will have to go there using a mean of transportation, since they do not want to get wet. Right now, it is late at night and they want to know if it is going to rain tomorrow around the Melbourne Airport to know if they need to schedule a shuttle bus to take them to the rented place.
#
# ---
#
# ### Project Objective
#
# > **Find if it will tomorrow around the Melbourne Airport.**
#
# ---
#
# ## Process
#
# This project will be divided into 3 parts:
#
# 1. **Initial Analysis of the Variables**
# 2. Baseline
# 3. Development of the Machine Learning Model

# %% [markdown]
# # Part 01 | Initial Analysis of the Variables

# %% [markdown]
# The objective of the first part of this project is to do an **initial data cleaning and manipulation** to get the dataset ready for the next part (Baseline).
#
# ---
#
# ## Specific Objective
#
# > - **Reduce the quantity of null values.**
# > - **Convert categorical variables to numerical.**
# > - **Filter the dataset, maintaining only the features that will be used later on.**
#
# ---
#
# ## Premises
#
# - The location is the **Melbourne Airport**.
# - Today is **25/06/2017**.
# - Right now is **nighttime**. Therefore, **not all features are available right now**.
# - The features available are:
#   - Maximum temperature
#   - Evaporation
#   - Sunshine
#   - Rain Today
#   - Rain Tomorrow
#   - All the other variables that were measured at 9 AM and 3 PM

# %% [markdown]
# ## Setup

# %% [markdown]
# ### Import Libraries and Adjust Some Settings

# %%
# Import libraries
import pandas as pd
import numpy as np

from sklearn.preprocessing import OrdinalEncoder

# %%
#Change the number maximum of columns that are displayed
pd.set_option('display.max_columns', 50)

# %% [markdown]
# ### Import Datasets

# %%
# Import the datasets
data = pd.read_csv('data/rain_data_aus.csv')
wind1 = pd.read_csv('data/wind_table_01.csv')
wind2 = pd.read_csv('data/wind_table_02.csv')
wind3 = pd.read_csv('data/wind_table_03.csv')
wind4 = pd.read_csv('data/wind_table_04.csv')
wind5 = pd.read_csv('data/wind_table_05.csv')
wind6 = pd.read_csv('data/wind_table_06.csv')
wind7 = pd.read_csv('data/wind_table_07.csv')
wind8 = pd.read_csv('data/wind_table_08.csv')

# %% [markdown]
# The dataset `data` has most the data, while the variable related to the wind is separated into 8 different datasets. However, the last two (`wind7` and `wind8`) seems to contain the same data.

# %%
# Check if the datasets 'wind7' and 'wind8' are the same
(wind7.shape[0] - wind7.isna().sum()) == np.sum(wind7 == wind8)
# Out:
# date             True
# location         True
# windgustdir      True
# windgustspeed    True
# winddir9am       True
# winddir3pm       True
# windspeed9am     True
# windspeed3pm     True
# dtype: bool

# %% [markdown]
# > Therefore, **they are the same dataset**. So, the `wind8` will not be considered.

# %%
#Concatenate all dataframes related to 'wind'
wind = pd.concat(objs=[wind1, wind2, wind3, wind4, wind5, wind6, wind7]).reset_index(drop=True)

#Check the results
wind
# Out:
#               date    location wind_gustdir  wind_gustspeed wind_dir9am  \
# 0       2007-11-01    Canberra           NW            30.0          SW
# 1       2007-11-02    Canberra          ENE            39.0           E
# 2       2007-11-03    Canberra           NW            85.0           N
# 3       2007-11-04    Canberra           NW            54.0         WNW
# 4       2007-11-05    Canberra          SSE            50.0         SSE
# ...            ...         ...          ...             ...         ...
# 142188  2017-06-25       Perth          NaN             NaN         NaN
# 142189  2017-06-25  SalmonGums          NaN             NaN         NaN
# 142190  2017-06-25     Walpole          NaN             NaN         NaN
# 142191  2017-06-25      Hobart          NaN             NaN         NaN
# 142192  2017-06-25  Launceston          NaN             NaN         NaN
#
#        wind_dir3pm  wind_speed9am  wind_speed3pm windgustdir  windgustspeed  \
# 0               NW            6.0           20.0         NaN            NaN
# 1                W            4.0           17.0         NaN            NaN
# 2              NNE            6.0            6.0         NaN            NaN
# 3                W           30.0           24.0         NaN            NaN
# 4              ESE           20.0           28.0         NaN            NaN
# ...            ...            ...            ...         ...            ...
# 142188         NaN            NaN            NaN           E           26.0
# 142189         NaN            NaN            NaN          SE           15.0
# 142190         NaN            NaN            NaN         SSW           20.0
# 142191         NaN            NaN            NaN          NW           50.0
# 142192         NaN            NaN            NaN          NW           50.0
#
#        winddir9am winddir3pm  windspeed9am  windspeed3pm
# 0             NaN        NaN           NaN           NaN
# 1             NaN        NaN           NaN           NaN
# 2             NaN        NaN           NaN           NaN
# 3             NaN        NaN           NaN           NaN
# 4             NaN        NaN           NaN           NaN
# ...           ...        ...           ...           ...
# 142188         SE         SE           4.0          11.0
# 142189        SSE          E           7.0           6.0
# 142190        WNW        SSW           6.0           6.0
# 142191        NNW        NNW          17.0          28.0
# 142192        NNW        NNW          15.0          17.0
#
# [142193 rows x 14 columns]

# %%
# Merge dataframes 'data' and 'wind'
df = pd.merge(left=data, right=wind, on=['date', 'location'])

#Check the result
df
# Out:
#               date location  mintemp  maxtemp  rainfall  evaporation  \
# 0       2008-12-01   Albury     13.4     22.9       0.6          NaN
# 1       2008-12-02   Albury      7.4     25.1       0.0          NaN
# 2       2008-12-03   Albury     12.9     25.7       0.0          NaN
# 3       2008-12-04   Albury      9.2     28.0       0.0          NaN
# 4       2008-12-05   Albury     17.5     32.3       1.0          NaN
# ...            ...      ...      ...      ...       ...          ...
# 142188  2017-06-20    Uluru      3.5     21.8       0.0          NaN
# 142189  2017-06-21    Uluru      2.8     23.4       0.0          NaN
# 142190  2017-06-22    Uluru      3.6     25.3       0.0          NaN
# 142191  2017-06-23    Uluru      5.4     26.9       0.0          NaN
# 142192  2017-06-24    Uluru      7.8     27.0       0.0          NaN
#
#         sunshine  humidity9am  humidity3pm  pressure9am  pressure3pm  \
# 0            NaN         71.0         22.0       1007.7       1007.1
# 1            NaN         44.0         25.0       1010.6       1007.8
# 2            NaN         38.0         30.0       1007.6       1008.7
# 3            NaN         45.0         16.0       1017.6       1012.8
# 4            NaN         82.0         33.0       1010.8       1006.0
# ...          ...          ...          ...          ...          ...
# 142188       NaN         59.0         27.0       1024.7       1021.2
# 142189       NaN         51.0         24.0       1024.6       1020.3
# 142190       NaN         56.0         21.0       1023.5       1019.1
# 142191       NaN         53.0         24.0       1021.0       1016.8
# 142192       NaN         51.0         24.0       1019.4       1016.5
#
#         cloud9am  cloud3pm  temp9am  temp3pm raintoday  amountOfRain  \
# 0            8.0       NaN     16.9     21.8        No           0.0
# 1            NaN       NaN     17.2     24.3        No           0.0
# 2            NaN       2.0     21.0     23.2        No           0.0
# 3            NaN       NaN     18.1     26.5        No           1.0
# 4            7.0       8.0     17.8     29.7        No           0.2
# ...          ...       ...      ...      ...       ...           ...
# 142188       NaN       NaN      9.4     20.9        No           0.0
# 142189       NaN       NaN     10.1     22.4        No           0.0
# 142190       NaN       NaN     10.9     24.5        No           0.0
# 142191       NaN       NaN     12.5     26.1        No           0.0
# 142192       3.0       2.0     15.1     26.0        No           0.0
#
#        raintomorrow   temp   humidity  precipitation3pm  precipitation9am  \
# 0                No  29.48  28.400000                12          5.115360
# 1                No  32.12   2.208569                10         21.497100
# 2                No  32.84  38.000000                17         20.782859
# 3                No  35.60  21.200000                 8         12.028646
# 4                No  40.76  41.600000                 9         11.883546
# ...             ...    ...        ...               ...               ...
# 142188           No  28.16  34.400000                12          5.848681
# 142189           No  30.08  30.800000                10          6.653879
# 142190           No  32.36  27.200000                 9         19.715976
# 142191           No  34.28  30.800000                12          0.985551
# 142192           No  34.40  30.800000                15          4.381481
#
#         modelo_vigente wind_gustdir  wind_gustspeed wind_dir9am wind_dir3pm  \
# 0             0.089825            W            44.0           W         WNW
# 1             0.023477          WNW            44.0         NNW         WSW
# 2             0.027580          WSW            46.0           W         WSW
# 3             0.023962           NE            24.0          SE           E
# 4             0.220164            W            41.0         ENE          NW
# ...                ...          ...             ...         ...         ...
# 142188        0.002556          NaN             NaN         NaN         NaN
# 142189        0.002053          NaN             NaN         NaN         NaN
# 142190        0.023350          NaN             NaN         NaN         NaN
# 142191        0.007195          NaN             NaN         NaN         NaN
# 142192        0.018811          NaN             NaN         NaN         NaN
#
#         wind_speed9am  wind_speed3pm windgustdir  windgustspeed winddir9am  \
# 0                20.0           24.0         NaN            NaN        NaN
# 1                 4.0           22.0         NaN            NaN        NaN
# 2                19.0           26.0         NaN            NaN        NaN
# 3                11.0            9.0         NaN            NaN        NaN
# 4                 7.0           20.0         NaN            NaN        NaN
# ...               ...            ...         ...            ...        ...
# 142188            NaN            NaN           E           31.0        ESE
# 142189            NaN            NaN           E           31.0         SE
# 142190            NaN            NaN         NNW           22.0         SE
# 142191            NaN            NaN           N           37.0         SE
# 142192            NaN            NaN          SE           28.0        SSE
#
#        winddir3pm  windspeed9am  windspeed3pm
# 0             NaN           NaN           NaN
# 1             NaN           NaN           NaN
# 2             NaN           NaN           NaN
# 3             NaN           NaN           NaN
# 4             NaN           NaN           NaN
# ...           ...           ...           ...
# 142188          E          15.0          13.0
# 142189        ENE          13.0          11.0
# 142190          N          13.0           9.0
# 142191        WNW           9.0           9.0
# 142192          N          13.0           7.0
#
# [142193 rows x 35 columns]

# %%
# Check the dataset's metadata
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 142193 entries, 0 to 142192
# Data columns (total 35 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   date              142193 non-null  object
#  1   location          142193 non-null  object
#  2   mintemp           141556 non-null  float64
#  3   maxtemp           141871 non-null  float64
#  4   rainfall          140787 non-null  float64
#  5   evaporation       81350 non-null   float64
#  6   sunshine          74377 non-null   float64
#  7   humidity9am       140419 non-null  float64
#  8   humidity3pm       138583 non-null  float64
#  9   pressure9am       128179 non-null  float64
#  10  pressure3pm       128212 non-null  float64
#  11  cloud9am          88536 non-null   float64
#  12  cloud3pm          85099 non-null   float64
#  13  temp9am           141289 non-null  float64
#  14  temp3pm           139467 non-null  float64
#  15  raintoday         140787 non-null  object
#  16  amountOfRain      142193 non-null  float64
#  17  raintomorrow      142193 non-null  object
#  18  temp              141871 non-null  float64
#  19  humidity          138583 non-null  float64
#  20  precipitation3pm  142193 non-null  int64
#  21  precipitation9am  142193 non-null  float64
#  22  modelo_vigente    142193 non-null  float64
#  23  wind_gustdir      36419 non-null   object
#  24  wind_gustspeed    36426 non-null   float64
#  25  wind_dir9am       36932 non-null   object
#  26  wind_dir3pm       38990 non-null   object
#  27  wind_speed9am     39300 non-null   float64
#  28  wind_speed3pm     39328 non-null   float64
#  29  windgustdir       96444 non-null   object
#  30  windgustspeed     96497 non-null   float64
#  31  winddir9am        95248 non-null   object
#  32  winddir3pm        99425 non-null   object
#  33  windspeed9am      101545 non-null  float64
#  34  windspeed3pm      100235 non-null  float64
# dtypes: float64(24), int64(1), object(10)
# memory usage: 39.1+ MB

# %% [markdown]
# Some features related to `wind` seems to have the same information and they might be repeated or complementary.

# %% [markdown]
# ## Analyze Columns Related to `wind`

# %%
# Check the variables related to the wind
df_wind = df[['wind_gustspeed', 'windgustspeed', 'wind_gustdir', 'windgustdir', 'wind_dir9am', 'winddir9am', 
              'wind_dir3pm', 'winddir3pm', 'windspeed9am', 'wind_speed9am', 'windspeed3pm', 'wind_speed3pm']]
df_wind
# Out:
#         wind_gustspeed  windgustspeed wind_gustdir windgustdir wind_dir9am  \
# 0                 44.0            NaN            W         NaN           W
# 1                 44.0            NaN          WNW         NaN         NNW
# 2                 46.0            NaN          WSW         NaN           W
# 3                 24.0            NaN           NE         NaN          SE
# 4                 41.0            NaN            W         NaN         ENE
# ...                ...            ...          ...         ...         ...
# 142188             NaN           31.0          NaN           E         NaN
# 142189             NaN           31.0          NaN           E         NaN
# 142190             NaN           22.0          NaN         NNW         NaN
# 142191             NaN           37.0          NaN           N         NaN
# 142192             NaN           28.0          NaN          SE         NaN
#
#        winddir9am wind_dir3pm winddir3pm  windspeed9am  wind_speed9am  \
# 0             NaN         WNW        NaN           NaN           20.0
# 1             NaN         WSW        NaN           NaN            4.0
# 2             NaN         WSW        NaN           NaN           19.0
# 3             NaN           E        NaN           NaN           11.0
# 4             NaN          NW        NaN           NaN            7.0
# ...           ...         ...        ...           ...            ...
# 142188        ESE         NaN          E          15.0            NaN
# 142189         SE         NaN        ENE          13.0            NaN
# 142190         SE         NaN          N          13.0            NaN
# 142191         SE         NaN        WNW           9.0            NaN
# 142192        SSE         NaN          N          13.0            NaN
#
#         windspeed3pm  wind_speed3pm
# 0                NaN           24.0
# 1                NaN           22.0
# 2                NaN           26.0
# 3                NaN            9.0
# 4                NaN           20.0
# ...              ...            ...
# 142188          13.0            NaN
# 142189          11.0            NaN
# 142190           9.0            NaN
# 142191           9.0            NaN
# 142192           7.0            NaN
#
# [142193 rows x 12 columns]

# %%
# Check if there are missing values for each pair
df_wind[((df_wind.wind_gustspeed.isna()) & (df_wind.windgustspeed.isna())) |((df_wind.wind_gustdir.isna()) & (df_wind.windgustdir.isna())) | ((df_wind.wind_dir9am.isna()) & (df_wind.winddir9am.isna()) | ((df_wind.wind_dir3pm.isna()) & (df_wind.winddir3pm.isna())) | ((df_wind.wind_speed9am.isna()) & (df_wind.windspeed9am.isna()) | ((df_wind.wind_speed3pm.isna()) & (df_wind.windspeed3pm.isna()))))]
# Out:
#         wind_gustspeed  windgustspeed wind_gustdir windgustdir wind_dir9am  \
# 14                50.0            NaN          WNW         NaN         NaN
# 25                57.0            NaN          WSW         NaN         NaN
# 63                 NaN            NaN          NaN         NaN           N
# 64                 NaN            NaN          NaN         NaN         NaN
# 74                39.0            NaN           NE         NaN           S
# ...                ...            ...          ...         ...         ...
# 141904             NaN           48.0          NaN         WSW         NaN
# 142051             NaN            NaN          NaN         NaN         NaN
# 142058             NaN           56.0          NaN         ENE         NaN
# 142156             NaN           26.0          NaN         ENE         NaN
# 142163             NaN           39.0          NaN         WNW         NaN
#
#        winddir9am wind_dir3pm winddir3pm  windspeed9am  wind_speed9am  \
# 14            NaN         WNW        NaN           NaN            NaN
# 25            NaN           W        NaN           NaN            0.0
# 63            NaN         NaN        NaN           NaN           13.0
# 64            NaN         NaN        NaN           NaN           11.0
# 74            NaN         NaN        NaN           NaN            7.0
# ...           ...         ...        ...           ...            ...
# 141904        NaN         NaN          W           0.0            NaN
# 142051        ESE         NaN          E          13.0            NaN
# 142058        NaN         NaN          N           0.0            NaN
# 142156        NaN         NaN          N           0.0            NaN
# 142163        NaN         NaN         NW           0.0            NaN
#
#         windspeed3pm  wind_speed3pm
# 14               NaN           22.0
# 25               NaN           26.0
# 63               NaN            9.0
# 64               NaN           11.0
# 74               NaN            0.0
# ...              ...            ...
# 141904          28.0            NaN
# 142051          24.0            NaN
# 142058          11.0            NaN
# 142156           7.0            NaN
# 142163          20.0            NaN
#
# [17525 rows x 12 columns]

# %% [markdown]
# It seems that when there is a value in the column with the underscore, there is no value for its pair and vice-versa. So they must be complementary.

# %% [markdown]
# ### `windgustdir` and `wind_gustdir`

# %%
# Number of nulls in each column
print('Quantity of nulls on wind_gustdir column:',df['wind_gustdir'].isna().sum())
print('Quantity of nulls on windgustdir column : ',df['windgustdir'].isna().sum())
# Out:
# Quantity of nulls on wind_gustdir column: 105774
# Quantity of nulls on windgustdir column :  45749

# %%
#Create a new column and add wind_gustdir values into it
df["wind_gustdir_complete"] = df["wind_gustdir"]

# %%
#Check if the new column were add
df.columns
# Out:
# Index(['date', 'location', 'mintemp', 'maxtemp', 'rainfall', 'evaporation',
#        'sunshine', 'humidity9am', 'humidity3pm', 'pressure9am', 'pressure3pm',
#        'cloud9am', 'cloud3pm', 'temp9am', 'temp3pm', 'raintoday',
#        'amountOfRain', 'raintomorrow', 'temp', 'humidity', 'precipitation3pm',
#        'precipitation9am', 'modelo_vigente', 'wind_gustdir', 'wind_gustspeed',
#        'wind_dir9am', 'wind_dir3pm', 'wind_speed9am', 'wind_speed3pm',
#        'windgustdir', 'windgustspeed', 'winddir9am', 'winddir3pm',
#        'windspeed9am', 'windspeed3pm', 'wind_gustdir_complete'],
#       dtype='object')

# %%
# Replace null values:
# How? Add windgustdir values into column wind_gustdir_complete (which aready have wind_gustdir values)
indices = df.loc[df['wind_gustdir'].isna(),'wind_gustdir'].index
values = df.iloc[indices,df.columns.get_loc("windgustdir")] #iloc on the lines:indices and columns:windgustdir
df.loc[df['wind_gustdir'].isna(),'wind_gustdir_complete'] = values #column wind_gustdir_complete

# %%
#After concatenate, it still having 9330 missing values
df['wind_gustdir_complete'].isna().sum()
# Out:
# 9330

# %%
# Check if the quantity of missing values of the new column it's correct
df[((df.wind_gustdir.isna()) & (df.windgustdir.isna()))].shape
# Out:
# (9330, 36)

# %% [markdown]
# > So, the column **wind_gustdir_complete** it will be used for windgustdir analysis. <br>
# The others (wind_gustdir and windgustdir) could be ignored.

# %% [markdown]
# ### `windgustspeed`   and `wind_gustspeed`

# %%
print('Quantity of nulls on wind_gustspeed column:',df['wind_gustspeed'].isna().sum())
print('Quantity of nulls on windgustspeed column : ',df['windgustspeed'].isna().sum())
# Out:
# Quantity of nulls on wind_gustspeed column: 105767
# Quantity of nulls on windgustspeed column :  45696

# %%
#Creating a new column and add wind_gustspeed values into it
df["wind_gustspeed_complete"] = df["wind_gustspeed"]

# %%
#Check if the new column were add
df.columns
# Out:
# Index(['date', 'location', 'mintemp', 'maxtemp', 'rainfall', 'evaporation',
#        'sunshine', 'humidity9am', 'humidity3pm', 'pressure9am', 'pressure3pm',
#        'cloud9am', 'cloud3pm', 'temp9am', 'temp3pm', 'raintoday',
#        'amountOfRain', 'raintomorrow', 'temp', 'humidity', 'precipitation3pm',
#        'precipitation9am', 'modelo_vigente', 'wind_gustdir', 'wind_gustspeed',
#        'wind_dir9am', 'wind_dir3pm', 'wind_speed9am', 'wind_speed3pm',
#        'windgustdir', 'windgustspeed', 'winddir9am', 'winddir3pm',
#        'windspeed9am', 'windspeed3pm', 'wind_gustdir_complete',
#        'wind_gustspeed_complete'],
#       dtype='object')

# %%
#Replacing null values:
# How? Add windgustspeed values into column wind_gustspeed_complete (which aready have wind_gustspeed values)
indices = df.loc[df['wind_gustspeed'].isna(),'wind_gustspeed'].index
values = df.iloc[indices,df.columns.get_loc("windgustspeed")] #iloc on the lines:indices and columns:windgustspeed
df.loc[df['wind_gustspeed'].isna(),'wind_gustspeed_complete'] = values #column wind_gustspeed_complete

# %%
#After concatenate, it still having 9330 missing values
df['wind_gustspeed_complete'].isna().sum()
# Out:
# 9270

# %%
# Check if the quantity of missing values of the new column it's correct
df[((df.wind_gustspeed.isna()) & (df.windgustspeed.isna()))].shape
# Out:
# (9270, 37)

# %% [markdown]
# > So, the column **wind_gustspeed_complete** it will be used for windgustspeed analysis. <br>
# The others (wind_gustspeed and windgustspeed) could be ignored.

# %% [markdown]
# ### `winddir9am` and `wind_dir9am`

# %%
print('Quantity of nulls on wind_dir9am column:',df['wind_dir9am'].isna().sum())
print('Quantity of nulls on winddir9am column : ',df['winddir9am'].isna().sum())
# Out:
# Quantity of nulls on wind_dir9am column: 105261
# Quantity of nulls on winddir9am column :  46945

# %%
#Creating a new column and add wind_gustspeed values into it
df["wind_dir9am_complete"] = df["wind_dir9am"]

# %%
#Check if the new column were add
df.columns
# Out:
# Index(['date', 'location', 'mintemp', 'maxtemp', 'rainfall', 'evaporation',
#        'sunshine', 'humidity9am', 'humidity3pm', 'pressure9am', 'pressure3pm',
#        'cloud9am', 'cloud3pm', 'temp9am', 'temp3pm', 'raintoday',
#        'amountOfRain', 'raintomorrow', 'temp', 'humidity', 'precipitation3pm',
#        'precipitation9am', 'modelo_vigente', 'wind_gustdir', 'wind_gustspeed',
#        'wind_dir9am', 'wind_dir3pm', 'wind_speed9am', 'wind_speed3pm',
#        'windgustdir', 'windgustspeed', 'winddir9am', 'winddir3pm',
#        'windspeed9am', 'windspeed3pm', 'wind_gustdir_complete',
#        'wind_gustspeed_complete', 'wind_dir9am_complete'],
#       dtype='object')

# %%
#Replacing null values:
# How? Add windgustspeed values into column wind_gustspeed_complete (which aready have wind_gustspeed values)
indices = df.loc[df['wind_dir9am'].isna(),'wind_dir9am'].index
values = df.iloc[indices,df.columns.get_loc("winddir9am")] #iloc on the lines:indices and columns:windgustspeed
df.loc[df['wind_dir9am'].isna(),'wind_dir9am_complete'] = values #column wind_gustspeed_complete

# %%
#After concatenate, it still having 9330 missing values
df['wind_dir9am_complete'].isna().sum()
# Out:
# 10013

# %%
# Check if the quantity of missing values of the new column it's correct
df[((df.wind_dir9am.isna()) & (df.winddir9am.isna()))].shape
# Out:
# (10013, 38)

# %% [markdown]
# > So, the column **wind_dir9am_complete** it will be used for winddir9am analysis. <br>
# The others (wind_dir9am and winddir9am) could be ignored.

# %% [markdown]
# ### `winddir3pm` and `wind_dir3pm`

# %%
print('Quantity of nulls on wind_dir3pm column:',df['wind_dir3pm'].isna().sum())
print('Quantity of nulls on winddir3pm column : ',df['winddir3pm'].isna().sum())
# Out:
# Quantity of nulls on wind_dir3pm column: 103203
# Quantity of nulls on winddir3pm column :  42768

# %%
#Creating a new column and add wind_gustspeed values into it
df["wind_dir3pm_complete"] = df["wind_dir3pm"]

# %%
#Check if the new column were add
df.columns
# Out:
# Index(['date', 'location', 'mintemp', 'maxtemp', 'rainfall', 'evaporation',
#        'sunshine', 'humidity9am', 'humidity3pm', 'pressure9am', 'pressure3pm',
#        'cloud9am', 'cloud3pm', 'temp9am', 'temp3pm', 'raintoday',
#        'amountOfRain', 'raintomorrow', 'temp', 'humidity', 'precipitation3pm',
#        'precipitation9am', 'modelo_vigente', 'wind_gustdir', 'wind_gustspeed',
#        'wind_dir9am', 'wind_dir3pm', 'wind_speed9am', 'wind_speed3pm',
#        'windgustdir', 'windgustspeed', 'winddir9am', 'winddir3pm',
#        'windspeed9am', 'windspeed3pm', 'wind_gustdir_complete',
#        'wind_gustspeed_complete', 'wind_dir9am_complete',
#        'wind_dir3pm_complete'],
#       dtype='object')

# %%
#Replacing null values:
# How? Add windgustspeed values into column wind_gustspeed_complete (which aready have wind_gustspeed values)
indices = df.loc[df['wind_dir3pm'].isna(),'wind_dir3pm'].index
values = df.iloc[indices,df.columns.get_loc("winddir3pm")] #iloc on the lines:indices and columns:windgustspeed
df.loc[df['wind_dir3pm'].isna(),'wind_dir3pm_complete'] = values #column wind_gustspeed_complete

# %%
#After concatenate, it still having 9330 missing values
df['wind_dir3pm_complete'].isna().sum()
# Out:
# 3778

# %%
# Check if the quantity of missing values of the new column it's correct
df[((df.wind_dir3pm.isna()) & (df.winddir3pm.isna()))].shape
# Out:
# (3778, 39)

# %% [markdown]
# > So, the column **wind_dir3pm_complete** it will be used for winddir3pm analysis. <br>
# The others (wind_dir3pm and winddir3pm) could be ignored.

# %% [markdown]
# ### `windspeed9am` and `wind_speed9am`

# %%
print('Quantity of nulls on wind_speed9am column:',df['wind_speed9am'].isna().sum())
print('Quantity of nulls on windspeed9am column : ',df['windspeed9am'].isna().sum())
# Out:
# Quantity of nulls on wind_speed9am column: 102893
# Quantity of nulls on windspeed9am column :  40648

# %%
#Creating a new column and add wind_gustspeed values into it
df["wind_speed9am_complete"] = df["wind_speed9am"]

# %%
#Check if the new column were add
df.columns
# Out:
# Index(['date', 'location', 'mintemp', 'maxtemp', 'rainfall', 'evaporation',
#        'sunshine', 'humidity9am', 'humidity3pm', 'pressure9am', 'pressure3pm',
#        'cloud9am', 'cloud3pm', 'temp9am', 'temp3pm', 'raintoday',
#        'amountOfRain', 'raintomorrow', 'temp', 'humidity', 'precipitation3pm',
#        'precipitation9am', 'modelo_vigente', 'wind_gustdir', 'wind_gustspeed',
#        'wind_dir9am', 'wind_dir3pm', 'wind_speed9am', 'wind_speed3pm',
#        'windgustdir', 'windgustspeed', 'winddir9am', 'winddir3pm',
#        'windspeed9am', 'windspeed3pm', 'wind_gustdir_complete',
#        'wind_gustspeed_complete', 'wind_dir9am_complete',
#        'wind_dir3pm_complete', 'wind_speed9am_complete'],
#       dtype='object')

# %%
#Replacing null values:
# How? Add windgustspeed values into column wind_gustspeed_complete (which aready have wind_gustspeed values)
indices = df.loc[df['wind_speed9am'].isna(),'wind_speed9am'].index
values = df.iloc[indices,df.columns.get_loc("windspeed9am")] #iloc on the lines:indices and columns:windgustspeed
df.loc[df['wind_speed9am'].isna(),'wind_speed9am_complete'] = values #column wind_gustspeed_complete

# %%
#After concatenate, it still having 9330 missing values
df['wind_speed9am_complete'].isna().sum()
# Out:
# 1348

# %%
# Check if the quantity of missing values of the new column it's correct
df[((df.wind_speed9am.isna()) & (df.windspeed9am.isna()))].shape
# Out:
# (1348, 40)

# %% [markdown]
# > So, the column **wind_speed9am_complete** it will be used for windspeed9am analysis. <br>
# The others (wind_speed9am and windspeed9am) could be ignored.

# %% [markdown]
# ### `windspeed3pm` and `wind_speed3pm`

# %%
print('Quantity of nulls on wind_speed3pm column:',df['wind_speed3pm'].isna().sum())
print('Quantity of nulls on windspeed3pm column : ',df['windspeed3pm'].isna().sum())
# Out:
# Quantity of nulls on wind_speed3pm column: 102865
# Quantity of nulls on windspeed3pm column :  41958

# %%
#Creating a new column and add wind_gustspeed values into it
df["wind_speed3pm_complete"] = df["wind_speed3pm"]

# %%
#Check if the new column were add
df.columns
# Out:
# Index(['date', 'location', 'mintemp', 'maxtemp', 'rainfall', 'evaporation',
#        'sunshine', 'humidity9am', 'humidity3pm', 'pressure9am', 'pressure3pm',
#        'cloud9am', 'cloud3pm', 'temp9am', 'temp3pm', 'raintoday',
#        'amountOfRain', 'raintomorrow', 'temp', 'humidity', 'precipitation3pm',
#        'precipitation9am', 'modelo_vigente', 'wind_gustdir', 'wind_gustspeed',
#        'wind_dir9am', 'wind_dir3pm', 'wind_speed9am', 'wind_speed3pm',
#        'windgustdir', 'windgustspeed', 'winddir9am', 'winddir3pm',
#        'windspeed9am', 'windspeed3pm', 'wind_gustdir_complete',
#        'wind_gustspeed_complete', 'wind_dir9am_complete',
#        'wind_dir3pm_complete', 'wind_speed9am_complete',
#        'wind_speed3pm_complete'],
#       dtype='object')

# %%
#Replacing null values:
# How? Add windgustspeed values into column wind_gustspeed_complete (which aready have wind_gustspeed values)
indices = df.loc[df['wind_speed3pm'].isna(),'wind_speed3pm'].index
values = df.iloc[indices,df.columns.get_loc("windspeed3pm")] #iloc on the lines:indices and columns:windgustspeed
df.loc[df['wind_speed3pm'].isna(),'wind_speed3pm_complete'] = values #column wind_gustspeed_complete

# %%
#After concatenate, it still having 9330 missing values
df['wind_speed3pm_complete'].isna().sum()
# Out:
# 2630

# %%
# Check if the quantity of missing values of the new column it's correct
df[((df.wind_speed3pm.isna()) & (df.windspeed3pm.isna()))].shape
# Out:
# (2630, 41)

# %% [markdown]
# > So, the column **wind_speed3pm_complete** it will be used for windspeed3pm analysis. <br>
# The others (wind_speed3pm and windspeed3pm) could be ignored.

# %% [markdown]
# ## Analyse the relation of columns created

# %%
# Number of missing values

print('MISSING VALUES')
print(f"wind_gustspeed_complete: {df['wind_gustspeed_complete'].isna().sum()}")
print(f"wind_gustdir_complete: {df['wind_gustdir_complete'].isna().sum()}")
print(f"wind_dir9am_complete: {df['wind_dir9am_complete'].isna().sum()}")
print(f"wind_dir3pm_complete: {df['wind_dir3pm_complete'].isna().sum()}")
print(f"wind_speed9am_complete: {df['wind_speed9am_complete'].isna().sum()}")
print(f"wind_speed3pm_complete: {df['wind_speed3pm_complete'].isna().sum()}")
# Out:
# MISSING VALUES
# wind_gustspeed_complete: 9270
# wind_gustdir_complete: 9330
# wind_dir9am_complete: 10013
# wind_dir3pm_complete: 3778
# wind_speed9am_complete: 1348
# wind_speed3pm_complete: 2630

# %%
# Check number of rows that have missing values in both pairs of speed and direction
print('GENERAL')
print(f"{(df['wind_gustspeed_complete'].isna() == df['wind_gustdir_complete'].isna()).value_counts()}")
print('\n9 AM')
print(f"{(df['wind_speed9am_complete'].isna() == df['wind_dir9am_complete'].isna()).value_counts()}")
print('\n3 PM')
print(f"{(df['wind_speed3pm_complete'].isna() == df['wind_dir3pm_complete'].isna()).value_counts()}")
# Out:
# GENERAL
# True     142133
# False        60
# dtype: int64
#
# 9 AM
# True     133528
# False      8665
# dtype: int64
#
# 3 PM
# True     141045
# False      1148
# dtype: int64

# %% [markdown]
# > **Most days have missing values in both features for each pair**, meaning that the equipment might had had a problem detecting the wind.

# %% [markdown]
# ## `date`

# %% [markdown]
# ### Convert `string` to `datetime`

# %%
# Convert string to datatime
df['date'] = pd.to_datetime(arg=df.date)

# Check the result
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 142193 entries, 0 to 142192
# Data columns (total 41 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   date                     142193 non-null  datetime64[ns]
#  1   location                 142193 non-null  object
#  2   mintemp                  141556 non-null  float64
#  3   maxtemp                  141871 non-null  float64
#  4   rainfall                 140787 non-null  float64
#  5   evaporation              81350 non-null   float64
#  6   sunshine                 74377 non-null   float64
#  7   humidity9am              140419 non-null  float64
#  8   humidity3pm              138583 non-null  float64
#  9   pressure9am              128179 non-null  float64
#  10  pressure3pm              128212 non-null  float64
#  11  cloud9am                 88536 non-null   float64
#  12  cloud3pm                 85099 non-null   float64
#  13  temp9am                  141289 non-null  float64
#  14  temp3pm                  139467 non-null  float64
#  15  raintoday                140787 non-null  object
#  16  amountOfRain             142193 non-null  float64
#  17  raintomorrow             142193 non-null  object
#  18  temp                     141871 non-null  float64
#  19  humidity                 138583 non-null  float64
#  20  precipitation3pm         142193 non-null  int64
#  21  precipitation9am         142193 non-null  float64
#  22  modelo_vigente           142193 non-null  float64
#  23  wind_gustdir             36419 non-null   object
#  24  wind_gustspeed           36426 non-null   float64
#  25  wind_dir9am              36932 non-null   object
#  26  wind_dir3pm              38990 non-null   object
#  27  wind_speed9am            39300 non-null   float64
#  28  wind_speed3pm            39328 non-null   float64
#  29  windgustdir              96444 non-null   object
#  30  windgustspeed            96497 non-null   float64
#  31  winddir9am               95248 non-null   object
#  32  winddir3pm               99425 non-null   object
#  33  windspeed9am             101545 non-null  float64
#  34  windspeed3pm             100235 non-null  float64
#  35  wind_gustdir_complete    132863 non-null  object
#  36  wind_gustspeed_complete  132923 non-null  float64
#  37  wind_dir9am_complete     132180 non-null  object
#  38  wind_dir3pm_complete     138415 non-null  object
#  39  wind_speed9am_complete   140845 non-null  float64
#  40  wind_speed3pm_complete   139563 non-null  float64
# dtypes: datetime64[ns](1), float64(27), int64(1), object(12)
# memory usage: 45.6+ MB

# %% [markdown]
# ## Filter the Dataset

# %% [markdown]
# ### Columns

# %%
# Columns Names
df.columns
# Out:
# Index(['date', 'location', 'mintemp', 'maxtemp', 'rainfall', 'evaporation',
#        'sunshine', 'humidity9am', 'humidity3pm', 'pressure9am', 'pressure3pm',
#        'cloud9am', 'cloud3pm', 'temp9am', 'temp3pm', 'raintoday',
#        'amountOfRain', 'raintomorrow', 'temp', 'humidity', 'precipitation3pm',
#        'precipitation9am', 'modelo_vigente', 'wind_gustdir', 'wind_gustspeed',
#        'wind_dir9am', 'wind_dir3pm', 'wind_speed9am', 'wind_speed3pm',
#        'windgustdir', 'windgustspeed', 'winddir9am', 'winddir3pm',
#        'windspeed9am', 'windspeed3pm', 'wind_gustdir_complete',
#        'wind_gustspeed_complete', 'wind_dir9am_complete',
#        'wind_dir3pm_complete', 'wind_speed9am_complete',
#        'wind_speed3pm_complete'],
#       dtype='object')

# %%
# Desired columns
columns = ['date', 'location', 'raintoday', 'raintomorrow','maxtemp', 'evaporation', 'sunshine', 'humidity9am', 'humidity3pm', 'pressure9am', 
           'pressure3pm', 'cloud9am', 'cloud3pm', 'temp9am', 'temp3pm', 'precipitation3pm', 'precipitation9am', 
           'wind_gustdir_complete', 'wind_gustspeed_complete', 'wind_dir9am_complete', 'wind_dir3pm_complete', 
           'wind_speed9am_complete', 'wind_speed3pm_complete']

# Filter the dataset
df_f = df[columns]

# Check the result
df_f.head()
# Out:
#         date location raintoday raintomorrow  maxtemp  evaporation  sunshine  \
# 0 2008-12-01   Albury        No           No     22.9          NaN       NaN
# 1 2008-12-02   Albury        No           No     25.1          NaN       NaN
# 2 2008-12-03   Albury        No           No     25.7          NaN       NaN
# 3 2008-12-04   Albury        No           No     28.0          NaN       NaN
# 4 2008-12-05   Albury        No           No     32.3          NaN       NaN
#
#    humidity9am  humidity3pm  pressure9am  pressure3pm  cloud9am  cloud3pm  \
# 0         71.0         22.0       1007.7       1007.1       8.0       NaN
# 1         44.0         25.0       1010.6       1007.8       NaN       NaN
# 2         38.0         30.0       1007.6       1008.7       NaN       2.0
# 3         45.0         16.0       1017.6       1012.8       NaN       NaN
# 4         82.0         33.0       1010.8       1006.0       7.0       8.0
#
#    temp9am  temp3pm  precipitation3pm  precipitation9am wind_gustdir_complete  \
# 0     16.9     21.8                12          5.115360                     W
# 1     17.2     24.3                10         21.497100                   WNW
# 2     21.0     23.2                17         20.782859                   WSW
# 3     18.1     26.5                 8         12.028646                    NE
# 4     17.8     29.7                 9         11.883546                     W
#
#    wind_gustspeed_complete wind_dir9am_complete wind_dir3pm_complete  \
# 0                     44.0                    W                  WNW
# 1                     44.0                  NNW                  WSW
# 2                     46.0                    W                  WSW
# 3                     24.0                   SE                    E
# 4                     41.0                  ENE                   NW
#
#    wind_speed9am_complete  wind_speed3pm_complete
# 0                    20.0                    24.0
# 1                     4.0                    22.0
# 2                    19.0                    26.0
# 3                    11.0                     9.0
# 4                     7.0                    20.0

# %% [markdown]
# ### Melbourne Airpot

# %%
# Filter the dataset
df_ma = df_f.query('location == "MelbourneAirport"').reset_index(drop=True)

# Check the result
df_ma
# Out:
#            date          location raintoday raintomorrow  maxtemp  \
# 0    2009-01-01  MelbourneAirport        No          Yes     19.9
# 1    2009-01-02  MelbourneAirport       Yes           No     17.8
# 2    2009-01-03  MelbourneAirport        No           No     21.1
# 3    2009-01-04  MelbourneAirport        No           No     29.2
# 4    2009-01-05  MelbourneAirport        No           No     29.0
# ...         ...               ...       ...          ...      ...
# 3004 2017-06-21  MelbourneAirport        No           No     13.2
# 3005 2017-06-22  MelbourneAirport        No           No     13.0
# 3006 2017-06-23  MelbourneAirport        No          Yes     13.2
# 3007 2017-06-24  MelbourneAirport       Yes           No     12.6
# 3008 2017-06-25  MelbourneAirport        No           No     13.9
#
#       evaporation  sunshine  humidity9am  humidity3pm  pressure9am  \
# 0             5.6       8.8         55.0         37.0       1005.1
# 1             7.2      12.9         50.0         43.0       1018.0
# 2             6.2      10.5         51.0         35.0       1020.8
# 3             6.4      12.5         67.0         23.0       1016.2
# 4             7.4      12.3         51.0         31.0       1011.9
# ...           ...       ...          ...          ...          ...
# 3004          0.6       0.0         97.0         78.0       1029.1
# 3005          0.6       0.0         78.0         60.0       1028.6
# 3006          1.6       6.0         68.0         66.0       1018.7
# 3007          1.8       5.6         80.0         50.0       1018.9
# 3008          2.8       3.8         72.0         58.0       1017.8
#
#       pressure3pm  cloud9am  cloud3pm  temp9am  temp3pm  precipitation3pm  \
# 0          1006.4       7.0       7.0     15.9     18.1                 9
# 1          1019.3       6.0       7.0     12.5     15.8                12
# 2          1017.6       1.0       7.0     13.4     19.6                12
# 3          1012.8       5.0       4.0     16.0     28.2                11
# 4          1010.3       6.0       2.0     19.4     27.1                15
# ...           ...       ...       ...      ...      ...               ...
# 3004       1028.6       7.0       7.0     10.1     11.8                12
# 3005       1025.0       7.0       7.0      7.4     12.9                11
# 3006       1014.0       1.0       7.0      9.6     11.2                11
# 3007       1017.5       2.0       7.0      8.0     11.2                12
# 3008       1015.5       7.0       7.0      8.1     12.2                11
#
#       precipitation9am wind_gustdir_complete  wind_gustspeed_complete  \
# 0             6.116945                    SW                     69.0
# 1             9.775912                   SSE                     56.0
# 2             5.986239                   SSE                     31.0
# 3             9.501362                   SSE                     35.0
# 4             6.677340                    SE                     33.0
# ...                ...                   ...                      ...
# 3004         17.328204                     N                     37.0
# 3005         15.581160                     N                     39.0
# 3006         -0.692281                     N                     57.0
# 3007          5.295213                    SW                     33.0
# 3008         11.477725                   NNW                     44.0
#
#      wind_dir9am_complete wind_dir3pm_complete  wind_speed9am_complete  \
# 0                       W                   SW                    33.0
# 1                      SW                  SSE                    31.0
# 2                       E                    S                    13.0
# 3                      NE                  SSE                     2.0
# 4                      SW                  SSE                     9.0
# ...                   ...                  ...                     ...
# 3004                    W                    S                     9.0
# 3005                    N                    N                    17.0
# 3006                  NNW                    N                    19.0
# 3007                    W                    W                    17.0
# 3008                    N                   NW                    26.0
#
#       wind_speed3pm_complete
# 0                       43.0
# 1                       26.0
# 2                       19.0
# 3                       20.0
# 4                       20.0
# ...                      ...
# 3004                    13.0
# 3005                    19.0
# 3006                    35.0
# 3007                     7.0
# 3008                    13.0
#
# [3009 rows x 23 columns]

# %% [markdown]
# #### Check if the Period is Complete

# %%
# Number of days from the first to last day
print(f"First Date: {df_ma['date'][0].strftime('%m/%d/%y')}")
print(f"Last Date: {df_ma['date'][df_ma.shape[0] - 1].strftime('%m/%d/%y')}")
print(f"Number of days: {(df_ma['date'][df_ma.shape[0] - 1] - df_ma['date'][0]).days} days")
print(f"Number of days in the dataset: {len(df_ma.date.unique())} days")
print(f"Number of missing days: {(df_ma['date'][df_ma.shape[0] - 1] - df_ma['date'][0]).days - len(df_ma.date.unique())} days")
print(f"Percentage of the days that we have informaiton: {(len(df_ma.date.unique()) / (df_ma['date'][df_ma.shape[0] - 1] - df_ma['date'][0]).days) * 100:.2f}%")
# Out:
# First Date: 01/01/09
# Last Date: 06/25/17
# Number of days: 3097 days
# Number of days in the dataset: 3009 days
# Number of missing days: 88 days
# Percentage of the days that we have informaiton: 97.16%

# %% [markdown]
# ### Melbourne

# %% [markdown]
# This dataset will be useful when inputting missing values in the dataframe `df_ma`.

# %%
# Filter the dataset
df_melbourne = df_f.query('location == "Melbourne"').reset_index(drop=True)

# Check the result
df_melbourne
# Out:
#            date   location raintoday raintomorrow  maxtemp  evaporation  \
# 0    2008-07-01  Melbourne       Yes           No     15.4          2.8
# 1    2008-07-02  Melbourne        No          Yes     14.5          5.2
# 2    2008-07-03  Melbourne       Yes           No     14.1          2.0
# 3    2008-07-04  Melbourne        No           No     14.5          1.8
# 4    2008-07-05  Melbourne        No           No     15.5          0.8
# ...         ...        ...       ...          ...      ...          ...
# 2430 2017-06-21  Melbourne        No           No     13.5          0.6
# 2431 2017-06-22  Melbourne        No           No     14.1          0.6
# 2432 2017-06-23  Melbourne        No          Yes     14.9          1.6
# 2433 2017-06-24  Melbourne       Yes           No     12.3          1.8
# 2434 2017-06-25  Melbourne        No          Yes     14.3          2.8
#
#       sunshine  humidity9am  humidity3pm  pressure9am  pressure3pm  cloud9am  \
# 0          7.0         60.0         38.0       1006.8       1010.3       1.0
# 1          4.0         66.0         52.0       1013.4       1016.2       7.0
# 2          0.8         72.0         58.0       1024.8       1024.3       7.0
# 3          4.2         87.0         49.0       1030.2       1029.0       7.0
# 4          8.4         81.0         52.0       1028.9       1024.9       2.0
# ...        ...          ...          ...          ...          ...       ...
# 2430       0.0        100.0         80.0       1028.8       1028.4       7.0
# 2431       0.0         93.0         56.0       1028.2       1024.8       7.0
# 2432       6.0         77.0         63.0       1018.8       1013.8       1.0
# 2433       5.6         75.0         63.0       1018.7       1017.4       2.0
# 2434       3.8         67.0         56.0       1017.4       1015.0       7.0
#
#       cloud3pm  temp9am  temp3pm  precipitation3pm  precipitation9am  \
# 0          7.0     11.0     14.6                15         14.086571
# 1          4.0     11.8     13.7                18          5.524671
# 2          7.0     10.6     13.9                10         12.489827
# 3          6.0     10.2     13.1                14          8.586301
# 4          5.0      5.5     14.6                 5         12.525412
# ...        ...      ...      ...               ...               ...
# 2430       7.0     11.2     12.7                11         11.796357
# 2431       7.0      7.5     13.5                18         17.534768
# 2432       7.0      9.1     12.5                12          8.856789
# 2433       7.0      9.6     11.2                 7          0.724738
# 2434       7.0      9.3     13.4                10         14.256116
#
#      wind_gustdir_complete  wind_gustspeed_complete wind_dir9am_complete  \
# 0                        W                     63.0                    W
# 1                        W                     63.0                    W
# 2                        W                     39.0                    W
# 3                        E                     19.0                  NNW
# 4                        N                     52.0                    N
# ...                    ...                      ...                  ...
# 2430                   NNW                     24.0                    W
# 2431                     N                     24.0                  NNE
# 2432                   NNW                     44.0                    N
# 2433                    SW                     30.0                  WNW
# 2434                    NW                     35.0                    N
#
#      wind_dir3pm_complete  wind_speed9am_complete  wind_speed3pm_complete
# 0                       W                    37.0                    35.0
# 1                     WSW                    30.0                    35.0
# 2                       W                    17.0                    24.0
# 3                       N                     9.0                     7.0
# 4                     NNE                    24.0                    30.0
# ...                   ...                     ...                     ...
# 2430                    S                     2.0                     9.0
# 2431                    N                     9.0                    11.0
# 2432                    N                    17.0                    19.0
# 2433                    S                    11.0                     2.0
# 2434                  NNW                    13.0                    17.0
#
# [2435 rows x 23 columns]

# %% [markdown]
# ## Missing Values

# %% [markdown]
# ### Check Missing Values

# %%
# Dataset's Metadata - Melbourne Airport
df_ma.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3009 entries, 0 to 3008
# Data columns (total 23 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   date                     3009 non-null   datetime64[ns]
#  1   location                 3009 non-null   object
#  2   raintoday                3009 non-null   object
#  3   raintomorrow             3009 non-null   object
#  4   maxtemp                  3009 non-null   float64
#  5   evaporation              3006 non-null   float64
#  6   sunshine                 3008 non-null   float64
#  7   humidity9am              3001 non-null   float64
#  8   humidity3pm              3000 non-null   float64
#  9   pressure9am              3009 non-null   float64
#  10  pressure3pm              3009 non-null   float64
#  11  cloud9am                 3009 non-null   float64
#  12  cloud3pm                 3008 non-null   float64
#  13  temp9am                  3009 non-null   float64
#  14  temp3pm                  3009 non-null   float64
#  15  precipitation3pm         3009 non-null   int64
#  16  precipitation9am         3009 non-null   float64
#  17  wind_gustdir_complete    2994 non-null   object
#  18  wind_gustspeed_complete  2994 non-null   float64
#  19  wind_dir9am_complete     2969 non-null   object
#  20  wind_dir3pm_complete     2996 non-null   object
#  21  wind_speed9am_complete   3008 non-null   float64
#  22  wind_speed3pm_complete   3009 non-null   float64
# dtypes: datetime64[ns](1), float64(15), int64(1), object(6)
# memory usage: 540.8+ KB

# %%
# Number of Missing Values
df_ma.isna().sum().sort_values(ascending=False)
# Out:
# wind_dir9am_complete       40
# wind_gustspeed_complete    15
# wind_gustdir_complete      15
# wind_dir3pm_complete       13
# humidity3pm                 9
# humidity9am                 8
# evaporation                 3
# cloud3pm                    1
# wind_speed9am_complete      1
# sunshine                    1
# wind_speed3pm_complete      0
# location                    0
# raintoday                   0
# raintomorrow                0
# maxtemp                     0
# cloud9am                    0
# pressure9am                 0
# pressure3pm                 0
# temp9am                     0
# temp3pm                     0
# precipitation3pm            0
# precipitation9am            0
# date                        0
# dtype: int64

# %%
# Percentage of Missing Values
(df_ma.isna().sum().sum() / df_ma.shape[0]) * 100
# Out:
# 3.5227650382186773

# %% [markdown]
# ### Input Missing Values

# %% [markdown]
# To input the missing values, we will use the data from **Melbourne**, since they are located in the same city, but just different parts of it.
#
# If the v**alue is not found** in the dataset, we will **drop** them because:
#
# - A climate feature can change abruptly from one day to the next one
# - The percentage of missing values is very small (~3.5%)

# %%
# Create a function to input missing values
def input_nan(df_base, df_get, feature):
    
    # Days that there is missing value in the feature
    dates = df_base[df_base[feature].isna()]['date'].values

    # Check if they exist in the 'Melbourne' dataset
    compare_feature = df_base[df_base['date'].isin(dates)].loc[:, ['date', feature]].merge(df_get[df_get['date'].isin(dates)].loc[:, ['date', feature]], on='date', suffixes=('_ma', '_melbourne'))
    
    # Create a new dataframe
    df_merged = df_base.merge(compare_feature, how='left', on='date')

    # Add a nre column with the final result of the feature
    df_merged[(feature + '_final')] = [df_merged.iloc[index, df_merged.columns.get_loc(feature)] if df_merged.iloc[index, df_merged.columns.get_loc(feature)] == df_merged.iloc[index, df_merged.columns.get_loc(feature)] else df_merged.iloc[index, df_merged.columns.get_loc(f'{feature}' + '_melbourne')]  for index in df_merged.index]

    return df_merged

# %% [markdown]
# #### `wind_dir9am_complete`

# %%
# Feature
feature = 'wind_dir9am_complete'

# Days that there is missing value in the feature
dates = df_ma[df_ma[feature].isna()]['date'].values

# Input missing values
df_input_done = input_nan(df_base=df_ma, df_get=df_melbourne, feature=feature)

# Check the result
df_input_done.loc[df_input_done['date'].isin(dates), ['date', feature, feature + '_final']]
# Out:
#            date wind_dir9am_complete wind_dir9am_complete_final
# 90   2009-04-01                  NaN                        NaN
# 141  2009-05-22                  NaN                        NaN
# 142  2009-05-23                  NaN                        NaN
# 153  2009-06-03                  NaN                        NaN
# 177  2009-06-27                  NaN                        NaN
# 315  2009-11-12                  NaN                        NaN
# 402  2010-02-07                  NaN                        NaN
# 492  2010-05-08                  NaN                        NaN
# 510  2010-05-26                  NaN                        NaN
# 513  2010-05-29                  NaN                        NaN
# 553  2010-07-08                  NaN                        NaN
# 847  2011-05-28                  NaN                        NaN
# 848  2011-05-29                  NaN                        NaN
# 1151 2012-03-27                  NaN                        NaN
# 1251 2012-07-05                  NaN                        NaN
# 1278 2012-08-01                  NaN                        NaN
# 1518 2013-05-27                  NaN                        NaN
# 1526 2013-06-04                  NaN                        NaN
# 1888 2014-06-01                  NaN                        NaN
# 1893 2014-06-06                  NaN                        NaN
# 1905 2014-06-18                  NaN                        NaN
# 1963 2014-08-15                  NaN                        NaN
# 2072 2014-12-02                  NaN                        NaN
# 2092 2014-12-22                  NaN                        NaN
# 2123 2015-01-22                  NaN                        NaN
# 2194 2015-04-03                  NaN                        NaN
# 2216 2015-04-25                  NaN                        NaN
# 2255 2015-06-03                  NaN                        NaN
# 2267 2015-06-15                  NaN                        NaN
# 2269 2015-06-17                  NaN                        NaN
# 2281 2015-06-29                  NaN                        NaN
# 2325 2015-08-12                  NaN                        NaN
# 2328 2015-08-15                  NaN                        NaN
# 2378 2015-10-04                  NaN                        NaN
# 2533 2016-03-07                  NaN                        NaN
# 2622 2016-06-04                  NaN                        NaN
# 2656 2016-07-08                  NaN                        NNE
# 2664 2016-07-16                  NaN                         NE
# 2731 2016-09-21                  NaN                        WSW
# 2733 2016-09-23                  NaN                        ESE

# %%
# Names of the columns
#print(df_input_done.columns)
#print(f'Number of columns: {len(df_input_done.columns)}')

# %% [markdown]
# #### `wind_gustspeed_complete`

# %%
# Feature
feature = 'wind_gustspeed_complete'

# Days that there is missing value in the feature
dates = df_ma[df_ma[feature].isna()]['date'].values

# Input missing values
df_input_done = input_nan(df_base=df_input_done, df_get=df_melbourne, feature=feature)

# Check the result
df_input_done.loc[df_input_done['date'].isin(dates), ['date', feature, feature + '_final']]
# Out:
#            date  wind_gustspeed_complete  wind_gustspeed_complete_final
# 92   2009-04-03                      NaN                            NaN
# 191  2009-07-11                      NaN                            NaN
# 252  2009-09-10                      NaN                            NaN
# 373  2010-01-09                      NaN                            NaN
# 730  2011-01-01                      NaN                            NaN
# 899  2011-07-19                      NaN                            NaN
# 964  2011-09-22                      NaN                            NaN
# 970  2011-09-28                      NaN                            NaN
# 1049 2011-12-16                      NaN                            NaN
# 1065 2012-01-01                      NaN                            NaN
# 1855 2014-04-29                      NaN                            NaN
# 1856 2014-04-30                      NaN                            NaN
# 1857 2014-05-01                      NaN                            NaN
# 2860 2017-01-28                      NaN                           43.0
# 2861 2017-01-29                      NaN                           30.0

# %%
# Names of the columns
#print(df_input_done.columns)
#print(f'Number of columns: {len(df_input_done.columns)}')

# %% [markdown]
# #### `wind_gustdir_complete`

# %%
# Feature
feature = 'wind_gustdir_complete'

# Days that there is missing value in the feature
dates = df_ma[df_ma[feature].isna()]['date'].values

# Input missing values
df_input_done = input_nan(df_base=df_input_done, df_get=df_melbourne, feature=feature)

# Check the result
df_input_done.loc[df_input_done['date'].isin(dates), ['date', feature, feature + '_final']]
# Out:
#            date wind_gustdir_complete wind_gustdir_complete_final
# 92   2009-04-03                   NaN                         NaN
# 191  2009-07-11                   NaN                         NaN
# 252  2009-09-10                   NaN                         NaN
# 373  2010-01-09                   NaN                         NaN
# 730  2011-01-01                   NaN                         NaN
# 899  2011-07-19                   NaN                         NaN
# 964  2011-09-22                   NaN                         NaN
# 970  2011-09-28                   NaN                         NaN
# 1049 2011-12-16                   NaN                         NaN
# 1065 2012-01-01                   NaN                         NaN
# 1855 2014-04-29                   NaN                         NaN
# 1856 2014-04-30                   NaN                         NaN
# 1857 2014-05-01                   NaN                         NaN
# 2860 2017-01-28                   NaN                           S
# 2861 2017-01-29                   NaN                         SSW

# %%
# Names of the columns
#print(df_input_done.columns)
#print(f'Number of columns: {len(df_input_done.columns)}')

# %% [markdown]
# #### `wind_dir3pm_complete`

# %%
# Feature
feature = 'wind_dir3pm_complete'

# Days that there is missing value in the feature
dates = df_ma[df_ma[feature].isna()]['date'].values

# Input missing values
df_input_done = input_nan(df_base=df_input_done, df_get=df_melbourne, feature=feature)

# Check the result
df_input_done.loc[df_input_done['date'].isin(dates), ['date', feature, feature + '_final']]
# Out:
#            date wind_dir3pm_complete wind_dir3pm_complete_final
# 519  2010-06-04                  NaN                        NaN
# 550  2010-07-05                  NaN                        NaN
# 589  2010-08-13                  NaN                        NaN
# 1252 2012-07-06                  NaN                        NaN
# 1526 2013-06-04                  NaN                        NaN
# 1868 2014-05-12                  NaN                        NaN
# 1905 2014-06-18                  NaN                        NaN
# 1937 2014-07-20                  NaN                        NaN
# 2585 2016-04-28                  NaN                        NaN
# 2623 2016-06-05                  NaN                        SSW
# 2994 2017-06-11                  NaN                        WSW
# 2996 2017-06-13                  NaN                         SW
# 2999 2017-06-16                  NaN                          S

# %%
# Names of the columns
#print(df_input_done.columns)
#print(f'Number of columns: {len(df_input_done.columns)}')

# %% [markdown]
# #### `humidity3pm`

# %%
# Feature
feature = 'humidity3pm'

# Days that there is missing value in the feature
dates = df_ma[df_ma[feature].isna()]['date'].values

# Input missing values
df_input_done = input_nan(df_base=df_input_done, df_get=df_melbourne, feature=feature)

# Check the result
df_input_done.loc[df_input_done['date'].isin(dates), ['date', feature, feature + '_final']]
# Out:
#            date  humidity3pm  humidity3pm_final
# 402  2010-02-07          NaN               40.0
# 403  2010-02-08          NaN               41.0
# 404  2010-02-09          NaN               53.0
# 405  2010-02-10          NaN               50.0
# 406  2010-02-11          NaN               64.0
# 407  2010-02-12          NaN               66.0
# 408  2010-02-13          NaN               76.0
# 409  2010-02-14          NaN               63.0
# 1416 2013-01-17          NaN               11.0

# %%
# Names of the columns
#print(df_input_done.columns)
#print(f'Number of columns: {len(df_input_done.columns)}')

# %% [markdown]
# #### `humidity9am`

# %%
# Feature
feature = 'humidity9am'

# Days that there is missing value in the feature
dates = df_ma[df_ma[feature].isna()]['date'].values

# Input missing values
df_input_done = input_nan(df_base=df_input_done, df_get=df_melbourne, feature=feature)

# Check the result
df_input_done.loc[df_input_done['date'].isin(dates), ['date', feature, feature + '_final']]
# Out:
#           date  humidity9am  humidity9am_final
# 403 2010-02-08          NaN               66.0
# 404 2010-02-09          NaN               58.0
# 405 2010-02-10          NaN               71.0
# 406 2010-02-11          NaN               67.0
# 407 2010-02-12          NaN               79.0
# 408 2010-02-13          NaN               83.0
# 409 2010-02-14          NaN               85.0
# 410 2010-02-15          NaN               72.0

# %%
# Names of the columns
#print(df_input_done.columns)
#print(f'Number of columns: {len(df_input_done.columns)}')

# %% [markdown]
# #### `evaporation`

# %%
# Feature
feature = 'evaporation'

# Days that there is missing value in the feature
dates = df_ma[df_ma[feature].isna()]['date'].values

# Input missing values
df_input_done = input_nan(df_base=df_input_done, df_get=df_melbourne, feature=feature)

# Check the result
df_input_done.loc[df_input_done['date'].isin(dates), ['date', feature, feature + '_final']]
# Out:
#            date  evaporation  evaporation_final
# 2214 2015-04-23          NaN                NaN
# 2461 2015-12-26          NaN                NaN
# 2535 2016-03-09          NaN                NaN

# %%
# Names of the columns
#print(df_input_done.columns)
#print(f'Number of columns: {len(df_input_done.columns)}')

# %% [markdown]
# #### `cloud3pm`

# %%
# Feature
feature = 'cloud3pm'

# Days that there is missing value in the feature
dates = df_ma[df_ma[feature].isna()]['date'].values

# Input missing values
df_input_done = input_nan(df_base=df_input_done, df_get=df_melbourne, feature=feature)

# Check the result
df_input_done.loc[df_input_done['date'].isin(dates), ['date', feature, feature + '_final']]
# Out:
#            date  cloud3pm  cloud3pm_final
# 2139 2015-02-07       NaN             NaN

# %%
# Names of the columns
#print(df_input_done.columns)
#print(f'Number of columns: {len(df_input_done.columns)}')#

# %% [markdown]
# #### `sunshine`

# %%
# Feature
feature = 'sunshine'

# Days that there is missing value in the feature
dates = df_ma[df_ma[feature].isna()]['date'].values

# Input missing values
df_input_done = input_nan(df_base=df_input_done, df_get=df_melbourne, feature=feature)

# Check the result
df_input_done.loc[df_input_done['date'].isin(dates), ['date', feature, feature + '_final']]
# Out:
#           date  sunshine  sunshine_final
# 642 2010-10-05       NaN             NaN

# %%
# Names of the columns
#print(df_input_done.columns)
#print(f'Number of columns: {len(df_input_done.columns)}')

# %% [markdown]
# #### `wind_speed9am_complete`

# %%
# Feature
feature = 'wind_speed9am_complete'

# Days that there is missing value in the feature
dates = df_ma[df_ma[feature].isna()]['date'].values

# Input missing values
df_input_done = input_nan(df_base=df_input_done, df_get=df_melbourne, feature=feature)

# Check the result
df_input_done.loc[df_input_done['date'].isin(dates), ['date', feature, feature + '_final']]
# Out:
#           date  wind_speed9am_complete  wind_speed9am_complete_final
# 142 2009-05-23                     NaN                           NaN

# %%
# Names of the columns
#print(df_input_done.columns)
#print(f'Number of columns: {len(df_input_done.columns)}')

# %% [markdown]
# ### Filter the Dataset

# %%
# Columns' Names
df_input_done.columns
# Out:
# Index(['date', 'location', 'raintoday', 'raintomorrow', 'maxtemp',
#        'evaporation', 'sunshine', 'humidity9am', 'humidity3pm', 'pressure9am',
#        'pressure3pm', 'cloud9am', 'cloud3pm', 'temp9am', 'temp3pm',
#        'precipitation3pm', 'precipitation9am', 'wind_gustdir_complete',
#        'wind_gustspeed_complete', 'wind_dir9am_complete',
#        'wind_dir3pm_complete', 'wind_speed9am_complete',
#        'wind_speed3pm_complete', 'wind_dir9am_complete_ma',
#        'wind_dir9am_complete_melbourne', 'wind_dir9am_complete_final',
#        'wind_gustspeed_complete_ma', 'wind_gustspeed_complete_melbourne',
#        'wind_gustspeed_complete_final', 'wind_gustdir_complete_ma',
#        'wind_gustdir_complete_melbourne', 'wind_gustdir_complete_final',
#        'wind_dir3pm_complete_ma', 'wind_dir3pm_complete_melbourne',
#        'wind_dir3pm_complete_final', 'humidity3pm_ma', 'humidity3pm_melbourne',
#        'humidity3pm_final', 'humidity9am_ma', 'humidity9am_melbourne',
#        'humidity9am_final', 'evaporation_ma', 'evaporation_melbourne',
#        'evaporation_final', 'cloud3pm_ma', 'cloud3pm_melbourne',
#        'cloud3pm_final', 'sunshine_ma', 'sunshine_melbourne', 'sunshine_final',
#        'wind_speed9am_complete_ma', 'wind_speed9am_complete_melbourne',
#        'wind_speed9am_complete_final'],
#       dtype='object')

# %%
# Desired columns
columns = ['date', 'location', 'raintoday', 'raintomorrow', 'maxtemp', 'evaporation_final', 'sunshine_final', 
           'humidity9am_final', 'humidity3pm_final', 'pressure9am', 'pressure3pm', 'cloud9am', 'cloud3pm_final', 
           'temp9am', 'temp3pm', 'precipitation3pm', 'precipitation9am', 'wind_gustdir_complete_final', 
           'wind_gustspeed_complete_final', 'wind_dir9am_complete_final', 
           'wind_dir3pm_complete_final', 'wind_speed9am_complete_final', 'wind_speed3pm_complete']

# Filter the dataset
df_final = df_input_done[columns]

# Check shape
print(f'Shape: {df_final.shape}')

# Check result
df_final.head()
# Out:
# Shape: (3009, 23)
#         date          location raintoday raintomorrow  maxtemp  \
# 0 2009-01-01  MelbourneAirport        No          Yes     19.9
# 1 2009-01-02  MelbourneAirport       Yes           No     17.8
# 2 2009-01-03  MelbourneAirport        No           No     21.1
# 3 2009-01-04  MelbourneAirport        No           No     29.2
# 4 2009-01-05  MelbourneAirport        No           No     29.0
#
#    evaporation_final  sunshine_final  humidity9am_final  humidity3pm_final  \
# 0                5.6             8.8               55.0               37.0
# 1                7.2            12.9               50.0               43.0
# 2                6.2            10.5               51.0               35.0
# 3                6.4            12.5               67.0               23.0
# 4                7.4            12.3               51.0               31.0
#
#    pressure9am  pressure3pm  cloud9am  cloud3pm_final  temp9am  temp3pm  \
# 0       1005.1       1006.4       7.0             7.0     15.9     18.1
# 1       1018.0       1019.3       6.0             7.0     12.5     15.8
# 2       1020.8       1017.6       1.0             7.0     13.4     19.6
# 3       1016.2       1012.8       5.0             4.0     16.0     28.2
# 4       1011.9       1010.3       6.0             2.0     19.4     27.1
#
#    precipitation3pm  precipitation9am wind_gustdir_complete_final  \
# 0                 9          6.116945                          SW
# 1                12          9.775912                         SSE
# 2                12          5.986239                         SSE
# 3                11          9.501362                         SSE
# 4                15          6.677340                          SE
#
#    wind_gustspeed_complete_final wind_dir9am_complete_final  \
# 0                           69.0                          W
# 1                           56.0                         SW
# 2                           31.0                          E
# 3                           35.0                         NE
# 4                           33.0                         SW
#
#   wind_dir3pm_complete_final  wind_speed9am_complete_final  \
# 0                         SW                          33.0
# 1                        SSE                          31.0
# 2                          S                          13.0
# 3                        SSE                           2.0
# 4                        SSE                           9.0
#
#    wind_speed3pm_complete
# 0                    43.0
# 1                    26.0
# 2                    19.0
# 3                    20.0
# 4                    20.0

# %% [markdown]
# ### Check Missing Values

# %%
# Number of Missing Values
df_final.isna().sum().sort_values(ascending=False)
# Out:
# wind_dir9am_complete_final       36
# wind_gustspeed_complete_final    13
# wind_gustdir_complete_final      13
# wind_dir3pm_complete_final        9
# evaporation_final                 3
# cloud3pm_final                    1
# wind_speed9am_complete_final      1
# sunshine_final                    1
# wind_speed3pm_complete            0
# humidity9am_final                 0
# location                          0
# raintoday                         0
# raintomorrow                      0
# maxtemp                           0
# cloud9am                          0
# humidity3pm_final                 0
# pressure9am                       0
# pressure3pm                       0
# temp9am                           0
# temp3pm                           0
# precipitation3pm                  0
# precipitation9am                  0
# date                              0
# dtype: int64

# %%
# Number of Missing Values
print(f'Only about {(df_final.isna().sum().sum() / df_final.shape[0]) * 100:.2f}% of rows of the dataset has missing values.')
# Out:
# Only about 2.56% of rows of the dataset has missing values.

# %% [markdown]
# These missing values that still existing were not found in the `Melboune` dataset, so they will be removed.

# %% [markdown]
# ### Filter the Dataset

# %%
# Number of rows with at least a missing value
df_final.isnull().any(axis=1).sum()
# Out:
# 61

# %%
print(f'At the end, there must be {df_final.shape[0] - df_final.isnull().any(axis=1).sum()} rows.')
# Out:
# At the end, there must be 2948 rows.

# %%
# Filter the dataset
df_final = df_final[~(df_final['wind_dir9am_complete_final'].isna()) & 
                    ~(df_final['wind_gustspeed_complete_final'].isna()) &
                    ~(df_final['wind_gustdir_complete_final'].isna()) &
                    ~(df_final['wind_dir3pm_complete_final'].isna()) &
                    ~(df_final['evaporation_final'].isna()) &
                    ~(df_final['cloud3pm_final'].isna()) &
                    ~(df_final['sunshine_final'].isna()) &
                    ~(df_final['wind_speed9am_complete_final'].isna())]

# Check result
df_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2948 entries, 0 to 3008
# Data columns (total 23 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   date                           2948 non-null   datetime64[ns]
#  1   location                       2948 non-null   object
#  2   raintoday                      2948 non-null   object
#  3   raintomorrow                   2948 non-null   object
#  4   maxtemp                        2948 non-null   float64
#  5   evaporation_final              2948 non-null   float64
#  6   sunshine_final                 2948 non-null   float64
#  7   humidity9am_final              2948 non-null   float64
#  8   humidity3pm_final              2948 non-null   float64
#  9   pressure9am                    2948 non-null   float64
#  10  pressure3pm                    2948 non-null   float64
#  11  cloud9am                       2948 non-null   float64
#  12  cloud3pm_final                 2948 non-null   float64
#  13  temp9am                        2948 non-null   float64
#  14  temp3pm                        2948 non-null   float64
#  15  precipitation3pm               2948 non-null   int64
#  16  precipitation9am               2948 non-null   float64
#  17  wind_gustdir_complete_final    2948 non-null   object
#  18  wind_gustspeed_complete_final  2948 non-null   float64
#  19  wind_dir9am_complete_final     2948 non-null   object
#  20  wind_dir3pm_complete_final     2948 non-null   object
#  21  wind_speed9am_complete_final   2948 non-null   float64
#  22  wind_speed3pm_complete         2948 non-null   float64
# dtypes: datetime64[ns](1), float64(15), int64(1), object(6)
# memory usage: 552.8+ KB

# %% [markdown]
# ## Encode Categorical Variables

# %% [markdown]
# ### `raintoday`

# %%
# Check the unique values
df_final.raintoday.unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
# Encode this variable
df_final['raintoday_int'] = df_final['raintoday'].apply(lambda x : 1 if x == 'Yes' else 0)

# Check the result
df_final
# Out:
#            date          location raintoday raintomorrow  maxtemp  \
# 0    2009-01-01  MelbourneAirport        No          Yes     19.9
# 1    2009-01-02  MelbourneAirport       Yes           No     17.8
# 2    2009-01-03  MelbourneAirport        No           No     21.1
# 3    2009-01-04  MelbourneAirport        No           No     29.2
# 4    2009-01-05  MelbourneAirport        No           No     29.0
# ...         ...               ...       ...          ...      ...
# 3004 2017-06-21  MelbourneAirport        No           No     13.2
# 3005 2017-06-22  MelbourneAirport        No           No     13.0
# 3006 2017-06-23  MelbourneAirport        No          Yes     13.2
# 3007 2017-06-24  MelbourneAirport       Yes           No     12.6
# 3008 2017-06-25  MelbourneAirport        No           No     13.9
#
#       evaporation_final  sunshine_final  humidity9am_final  humidity3pm_final  \
# 0                   5.6             8.8               55.0               37.0
# 1                   7.2            12.9               50.0               43.0
# 2                   6.2            10.5               51.0               35.0
# 3                   6.4            12.5               67.0               23.0
# 4                   7.4            12.3               51.0               31.0
# ...                 ...             ...                ...                ...
# 3004                0.6             0.0               97.0               78.0
# 3005                0.6             0.0               78.0               60.0
# 3006                1.6             6.0               68.0               66.0
# 3007                1.8             5.6               80.0               50.0
# 3008                2.8             3.8               72.0               58.0
#
#       pressure9am  pressure3pm  cloud9am  cloud3pm_final  temp9am  temp3pm  \
# 0          1005.1       1006.4       7.0             7.0     15.9     18.1
# 1          1018.0       1019.3       6.0             7.0     12.5     15.8
# 2          1020.8       1017.6       1.0             7.0     13.4     19.6
# 3          1016.2       1012.8       5.0             4.0     16.0     28.2
# 4          1011.9       1010.3       6.0             2.0     19.4     27.1
# ...           ...          ...       ...             ...      ...      ...
# 3004       1029.1       1028.6       7.0             7.0     10.1     11.8
# 3005       1028.6       1025.0       7.0             7.0      7.4     12.9
# 3006       1018.7       1014.0       1.0             7.0      9.6     11.2
# 3007       1018.9       1017.5       2.0             7.0      8.0     11.2
# 3008       1017.8       1015.5       7.0             7.0      8.1     12.2
#
#       precipitation3pm  precipitation9am wind_gustdir_complete_final  \
# 0                    9          6.116945                          SW
# 1                   12          9.775912                         SSE
# 2                   12          5.986239                         SSE
# 3                   11          9.501362                         SSE
# 4                   15          6.677340                          SE
# ...                ...               ...                         ...
# 3004                12         17.328204                           N
# 3005                11         15.581160                           N
# 3006                11         -0.692281                           N
# 3007                12          5.295213                          SW
# 3008                11         11.477725                         NNW
#
#       wind_gustspeed_complete_final wind_dir9am_complete_final  \
# 0                              69.0                          W
# 1                              56.0                         SW
# 2                              31.0                          E
# 3                              35.0                         NE
# 4                              33.0                         SW
# ...                             ...                        ...
# 3004                           37.0                          W
# 3005                           39.0                          N
# 3006                           57.0                        NNW
# 3007                           33.0                          W
# 3008                           44.0                          N
#
#      wind_dir3pm_complete_final  wind_speed9am_complete_final  \
# 0                            SW                          33.0
# 1                           SSE                          31.0
# 2                             S                          13.0
# 3                           SSE                           2.0
# 4                           SSE                           9.0
# ...                         ...                           ...
# 3004                          S                           9.0
# 3005                          N                          17.0
# 3006                          N                          19.0
# 3007                          W                          17.0
# 3008                         NW                          26.0
#
#       wind_speed3pm_complete  raintoday_int
# 0                       43.0              0
# 1                       26.0              1
# 2                       19.0              0
# 3                       20.0              0
# 4                       20.0              0
# ...                      ...            ...
# 3004                    13.0              0
# 3005                    19.0              0
# 3006                    35.0              0
# 3007                     7.0              1
# 3008                    13.0              0
#
# [2948 rows x 24 columns]

# %% [markdown]
# ### `raintomorrow`

# %%
# Check the unique values
df_final.raintomorrow.unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
# Encode this variable
df_final['raintomorrow_int'] = df_final.raintomorrow.apply(lambda x : 1 if x == 'Yes' else 0)

# Check the result
df_final
# Out:
#            date          location raintoday raintomorrow  maxtemp  \
# 0    2009-01-01  MelbourneAirport        No          Yes     19.9
# 1    2009-01-02  MelbourneAirport       Yes           No     17.8
# 2    2009-01-03  MelbourneAirport        No           No     21.1
# 3    2009-01-04  MelbourneAirport        No           No     29.2
# 4    2009-01-05  MelbourneAirport        No           No     29.0
# ...         ...               ...       ...          ...      ...
# 3004 2017-06-21  MelbourneAirport        No           No     13.2
# 3005 2017-06-22  MelbourneAirport        No           No     13.0
# 3006 2017-06-23  MelbourneAirport        No          Yes     13.2
# 3007 2017-06-24  MelbourneAirport       Yes           No     12.6
# 3008 2017-06-25  MelbourneAirport        No           No     13.9
#
#       evaporation_final  sunshine_final  humidity9am_final  humidity3pm_final  \
# 0                   5.6             8.8               55.0               37.0
# 1                   7.2            12.9               50.0               43.0
# 2                   6.2            10.5               51.0               35.0
# 3                   6.4            12.5               67.0               23.0
# 4                   7.4            12.3               51.0               31.0
# ...                 ...             ...                ...                ...
# 3004                0.6             0.0               97.0               78.0
# 3005                0.6             0.0               78.0               60.0
# 3006                1.6             6.0               68.0               66.0
# 3007                1.8             5.6               80.0               50.0
# 3008                2.8             3.8               72.0               58.0
#
#       pressure9am  pressure3pm  cloud9am  cloud3pm_final  temp9am  temp3pm  \
# 0          1005.1       1006.4       7.0             7.0     15.9     18.1
# 1          1018.0       1019.3       6.0             7.0     12.5     15.8
# 2          1020.8       1017.6       1.0             7.0     13.4     19.6
# 3          1016.2       1012.8       5.0             4.0     16.0     28.2
# 4          1011.9       1010.3       6.0             2.0     19.4     27.1
# ...           ...          ...       ...             ...      ...      ...
# 3004       1029.1       1028.6       7.0             7.0     10.1     11.8
# 3005       1028.6       1025.0       7.0             7.0      7.4     12.9
# 3006       1018.7       1014.0       1.0             7.0      9.6     11.2
# 3007       1018.9       1017.5       2.0             7.0      8.0     11.2
# 3008       1017.8       1015.5       7.0             7.0      8.1     12.2
#
#       precipitation3pm  precipitation9am wind_gustdir_complete_final  \
# 0                    9          6.116945                          SW
# 1                   12          9.775912                         SSE
# 2                   12          5.986239                         SSE
# 3                   11          9.501362                         SSE
# 4                   15          6.677340                          SE
# ...                ...               ...                         ...
# 3004                12         17.328204                           N
# 3005                11         15.581160                           N
# 3006                11         -0.692281                           N
# 3007                12          5.295213                          SW
# 3008                11         11.477725                         NNW
#
#       wind_gustspeed_complete_final wind_dir9am_complete_final  \
# 0                              69.0                          W
# 1                              56.0                         SW
# 2                              31.0                          E
# 3                              35.0                         NE
# 4                              33.0                         SW
# ...                             ...                        ...
# 3004                           37.0                          W
# 3005                           39.0                          N
# 3006                           57.0                        NNW
# 3007                           33.0                          W
# 3008                           44.0                          N
#
#      wind_dir3pm_complete_final  wind_speed9am_complete_final  \
# 0                            SW                          33.0
# 1                           SSE                          31.0
# 2                             S                          13.0
# 3                           SSE                           2.0
# 4                           SSE                           9.0
# ...                         ...                           ...
# 3004                          S                           9.0
# 3005                          N                          17.0
# 3006                          N                          19.0
# 3007                          W                          17.0
# 3008                         NW                          26.0
#
#       wind_speed3pm_complete  raintoday_int  raintomorrow_int
# 0                       43.0              0                 1
# 1                       26.0              1                 0
# 2                       19.0              0                 0
# 3                       20.0              0                 0
# 4                       20.0              0                 0
# ...                      ...            ...               ...
# 3004                    13.0              0                 0
# 3005                    19.0              0                 0
# 3006                    35.0              0                 1
# 3007                     7.0              1                 0
# 3008                    13.0              0                 0
#
# [2948 rows x 25 columns]

# %% [markdown]
# ### Features Related to Wind Direction

# %%
# Function to encode the features realted to wind direction
def encode_winddir(df_column):
    
    # Instance the encoder
    encoder = OrdinalEncoder(categories=[['N', 'NNE', 'NE', 'ENE', 'E', 'ESE', 'SE', 'SSE', 'S', 'SSW', 'SW', 'WSW', 'W', 'WNW', 'NW', 'NNW']])

    # Train the encoder
    result = encoder.fit_transform(df_column)
    
    result_int = [int(item[0]) for item in result]
    
    return result_int

# %%
# Check dataframe shape
df_final.shape
# Out:
# (2948, 25)

# %%
# Create a new column for each feature related to the wind direction
for feature in ['wind_gustdir_complete_final', 'wind_dir9am_complete_final', 'wind_dir3pm_complete_final']:
    df_final[feature + '_int'] = encode_winddir(df_final[[feature]])

# %%
# Check dataframe shape
df_final.shape
# Out:
# (2948, 28)

# %% [markdown]
# ## Final Dataset

# %% [markdown]
# ### Filter the Dataset

# %% [markdown]
# #### Columns

# %%
# Columns' Names
df_final.columns
# Out:
# Index(['date', 'location', 'raintoday', 'raintomorrow', 'maxtemp',
#        'evaporation_final', 'sunshine_final', 'humidity9am_final',
#        'humidity3pm_final', 'pressure9am', 'pressure3pm', 'cloud9am',
#        'cloud3pm_final', 'temp9am', 'temp3pm', 'precipitation3pm',
#        'precipitation9am', 'wind_gustdir_complete_final',
#        'wind_gustspeed_complete_final', 'wind_dir9am_complete_final',
#        'wind_dir3pm_complete_final', 'wind_speed9am_complete_final',
#        'wind_speed3pm_complete', 'raintoday_int', 'raintomorrow_int',
#        'wind_gustdir_complete_final_int', 'wind_dir9am_complete_final_int',
#        'wind_dir3pm_complete_final_int'],
#       dtype='object')

# %%
# Desired columns
columns = ['date', 'location', 'maxtemp', 'evaporation_final', 'sunshine_final', 'humidity9am_final', 'humidity3pm_final', 
           'pressure9am', 'pressure3pm', 'cloud9am', 'cloud3pm_final', 'temp9am', 'temp3pm', 'precipitation3pm',
           'precipitation9am', 'wind_speed9am_complete_final', 'wind_speed3pm_complete', 'wind_dir9am_complete_final_int',
           'wind_dir3pm_complete_final_int', 'raintoday_int', 'raintomorrow_int']

# Filter the dataset
df_final = df_final[columns]

# Check shape
print(f'Shape: {df_final.shape}')

# Check result
df_final.head()
# Out:
# Shape: (2948, 21)
#         date          location  maxtemp  evaporation_final  sunshine_final  \
# 0 2009-01-01  MelbourneAirport     19.9                5.6             8.8
# 1 2009-01-02  MelbourneAirport     17.8                7.2            12.9
# 2 2009-01-03  MelbourneAirport     21.1                6.2            10.5
# 3 2009-01-04  MelbourneAirport     29.2                6.4            12.5
# 4 2009-01-05  MelbourneAirport     29.0                7.4            12.3
#
#    humidity9am_final  humidity3pm_final  pressure9am  pressure3pm  cloud9am  \
# 0               55.0               37.0       1005.1       1006.4       7.0
# 1               50.0               43.0       1018.0       1019.3       6.0
# 2               51.0               35.0       1020.8       1017.6       1.0
# 3               67.0               23.0       1016.2       1012.8       5.0
# 4               51.0               31.0       1011.9       1010.3       6.0
#
#    cloud3pm_final  temp9am  temp3pm  precipitation3pm  precipitation9am  \
# 0             7.0     15.9     18.1                 9          6.116945
# 1             7.0     12.5     15.8                12          9.775912
# 2             7.0     13.4     19.6                12          5.986239
# 3             4.0     16.0     28.2                11          9.501362
# 4             2.0     19.4     27.1                15          6.677340
#
#    wind_speed9am_complete_final  wind_speed3pm_complete  \
# 0                          33.0                    43.0
# 1                          31.0                    26.0
# 2                          13.0                    19.0
# 3                           2.0                    20.0
# 4                           9.0                    20.0
#
#    wind_dir9am_complete_final_int  wind_dir3pm_complete_final_int  \
# 0                              12                              10
# 1                              10                               7
# 2                               4                               8
# 3                               2                               7
# 4                              10                               7
#
#    raintoday_int  raintomorrow_int
# 0              0                 1
# 1              1                 0
# 2              0                 0
# 3              0                 0
# 4              0                 0

# %% [markdown]
# #### Rows

# %%
# Filter the dataset for today
df_today = df_final.iloc[[-1]]

# Check the result
df_today
# Out:
#            date          location  maxtemp  evaporation_final  sunshine_final  \
# 3008 2017-06-25  MelbourneAirport     13.9                2.8             3.8
#
#       humidity9am_final  humidity3pm_final  pressure9am  pressure3pm  \
# 3008               72.0               58.0       1017.8       1015.5
#
#       cloud9am  cloud3pm_final  temp9am  temp3pm  precipitation3pm  \
# 3008       7.0             7.0      8.1     12.2                11
#
#       precipitation9am  wind_speed9am_complete_final  wind_speed3pm_complete  \
# 3008         11.477725                          26.0                    13.0
#
#       wind_dir9am_complete_final_int  wind_dir3pm_complete_final_int  \
# 3008                               0                              14
#
#       raintoday_int  raintomorrow_int
# 3008              0                 0

# %%
# Filter the dataset for the final one
df_final = df_final.iloc[: df_final.shape[0] - 1, :]

# Check the result
df_final
# Out:
#            date          location  maxtemp  evaporation_final  sunshine_final  \
# 0    2009-01-01  MelbourneAirport     19.9                5.6             8.8
# 1    2009-01-02  MelbourneAirport     17.8                7.2            12.9
# 2    2009-01-03  MelbourneAirport     21.1                6.2            10.5
# 3    2009-01-04  MelbourneAirport     29.2                6.4            12.5
# 4    2009-01-05  MelbourneAirport     29.0                7.4            12.3
# ...         ...               ...      ...                ...             ...
# 3003 2017-06-20  MelbourneAirport     15.3                2.4             8.8
# 3004 2017-06-21  MelbourneAirport     13.2                0.6             0.0
# 3005 2017-06-22  MelbourneAirport     13.0                0.6             0.0
# 3006 2017-06-23  MelbourneAirport     13.2                1.6             6.0
# 3007 2017-06-24  MelbourneAirport     12.6                1.8             5.6
#
#       humidity9am_final  humidity3pm_final  pressure9am  pressure3pm  \
# 0                  55.0               37.0       1005.1       1006.4
# 1                  50.0               43.0       1018.0       1019.3
# 2                  51.0               35.0       1020.8       1017.6
# 3                  67.0               23.0       1016.2       1012.8
# 4                  51.0               31.0       1011.9       1010.3
# ...                 ...                ...          ...          ...
# 3003               80.0               56.0       1028.2       1024.7
# 3004               97.0               78.0       1029.1       1028.6
# 3005               78.0               60.0       1028.6       1025.0
# 3006               68.0               66.0       1018.7       1014.0
# 3007               80.0               50.0       1018.9       1017.5
#
#       cloud9am  cloud3pm_final  temp9am  temp3pm  precipitation3pm  \
# 0          7.0             7.0     15.9     18.1                 9
# 1          6.0             7.0     12.5     15.8                12
# 2          1.0             7.0     13.4     19.6                12
# 3          5.0             4.0     16.0     28.2                11
# 4          6.0             2.0     19.4     27.1                15
# ...        ...             ...      ...      ...               ...
# 3003       1.0             7.0      7.7     14.4                12
# 3004       7.0             7.0     10.1     11.8                12
# 3005       7.0             7.0      7.4     12.9                11
# 3006       1.0             7.0      9.6     11.2                11
# 3007       2.0             7.0      8.0     11.2                12
#
#       precipitation9am  wind_speed9am_complete_final  wind_speed3pm_complete  \
# 0             6.116945                          33.0                    43.0
# 1             9.775912                          31.0                    26.0
# 2             5.986239                          13.0                    19.0
# 3             9.501362                           2.0                    20.0
# 4             6.677340                           9.0                    20.0
# ...                ...                           ...                     ...
# 3003          9.271984                          24.0                    30.0
# 3004         17.328204                           9.0                    13.0
# 3005         15.581160                          17.0                    19.0
# 3006         -0.692281                          19.0                    35.0
# 3007          5.295213                          17.0                     7.0
#
#       wind_dir9am_complete_final_int  wind_dir3pm_complete_final_int  \
# 0                                 12                              10
# 1                                 10                               7
# 2                                  4                               8
# 3                                  2                               7
# 4                                 10                               7
# ...                              ...                             ...
# 3003                               0                               0
# 3004                              12                               8
# 3005                               0                               0
# 3006                              15                               0
# 3007                              12                              12
#
#       raintoday_int  raintomorrow_int
# 0                 0                 1
# 1                 1                 0
# 2                 0                 0
# 3                 0                 0
# 4                 0                 0
# ...             ...               ...
# 3003              0                 0
# 3004              0                 0
# 3005              0                 0
# 3006              0                 1
# 3007              1                 0
#
# [2947 rows x 21 columns]

# %%
# Original Dataset
print(f'The original dataset with information about the Melbourne Airport had {df_ma.shape[0]} rows and the final one has {df_final.shape[0]} rows, which means that about {100 - (df_final.shape[0] / df_ma.shape[0]) * 100:.2f}% of the dataset original dataset will not be used.')
# Out:
# The original dataset with information about the Melbourne Airport had 3009 rows and the final one has 2947 rows, which means that about 2.06% of the dataset original dataset will not be used.

# %% [markdown]
# ## Export dataset

# %%
# Export the final dataframe
df_final.to_csv('exported_df/complete_dataset.csv', index=False)

# Export the dataframe for today
df_today.to_csv('exported_df/today_dataset.csv', index=False)
